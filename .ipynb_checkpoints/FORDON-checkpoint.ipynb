# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
import requests

# %%
executable_path = {"executable_path": "chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Desktop/jupyter_projects/py3virtualenvs/jupyter3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %% [markdown]
# # Superbowl Website Game Stats

# %%
superbowl_url = "https://www.nfl.com/gamecenter/2019020300/2018/POST4/patriots@rams"
browser.visit(superbowl_url)
html = browser.html
soup = bs(html,"html.parser")

# %%
# print(soup.prettify())

# %%
# news_title = soup.find("div",class_="content_title").text
# paragraph_text = soup.find("div", class_="article_teaser_body").text
# print(f"Title: {news_title}")
# print(f"paragraph: {paragraph_text}")

# %%
quarter_tables = pd.read_html(superbowl_url)

# %%
game_score = 
team_img =
team_name =

# %%
# team_one = browser.find_by_css('class="css-11q1ez0""img")
# team_two = browser.find_by_css('class="css-sigfkv"'')   
                               
# print(team_one)

# %% [markdown]
# # Backround Pic

# %%
img_url = 'https://www.nfl.com/super-bowl'
browser.visit(img_url)
html = browser.html
soup = bs(html, "html.parser")

# %%
# print(soup.prettify())

# %%
img = soup.find('img',{'data-test-id':"facemask-image-container"})
# img_url = "https://www.jpl.nasa.gov" + img
print(img)
# Out:
# <img alt="An image of Jennifer Lopez and Shakira with Pepsi and Super Bowl logos." class="css-1nedasa" data-test-id="facemask-image-container" sizes="100vw" src="https://imagecomposer.nfl.com/?l=http://static.nfl.com/static/content/public/photo/2019/09/26/0ap3000001059134.jpg&amp;f=jpg&amp;w=840&amp;c=80" srcset="https://imagecomposer.nfl.com/?l=http://static.nfl.com/static/content/public/photo/2019/09/26/0ap3000001059134.jpg&amp;f=jpg&amp;w=480&amp;c=80 480w,https://imagecomposer.nfl.com/?l=http://static.nfl.com/static/content/public/photo/2019/09/26/0ap3000001059134.jpg&amp;f=jpg&amp;w=768&amp;c=80 768w,https://imagecomposer.nfl.com/?l=http://static.nfl.com/static/content/public/photo/2019/09/26/0ap3000001059134.jpg&amp;f=jpg&amp;w=992&amp;c=80 992w,https://imagecomposer.nfl.com/?l=http://static.nfl.com/static/content/public/photo/2019/09/26/0ap3000001059134.jpg&amp;f=jpg&amp;w=1280&amp;c=80 1280w" width="840"/>

# %%
img['src']
# Out:
# 'https://imagecomposer.nfl.com/?l=http://static.nfl.com/static/content/public/photo/2019/09/26/0ap3000001059134.jpg&f=jpg&w=840&c=80'

# %% [markdown]
# #  National Football League stadiums Table

# %%
table_url = "https://en.wikipedia.org/wiki/List_of_current_National_Football_League_stadiums"
html = requests.get(table_url)
soup = bs(html.text,"html.parser")

# %%
test = soup.findAll('td')

for i in test:
    x = i.findAll('a')
    for y in x:
        print(y)
# Out:
# <a class="image" href="/wiki/File:Chiefsgame.jpg"><img alt="Chiefsgame.jpg" data-file-height="1704" data-file-width="2272" decoding="async" height="90" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Chiefsgame.jpg/120px-Chiefsgame.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Chiefsgame.jpg/180px-Chiefsgame.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Chiefsgame.jpg/240px-Chiefsgame.jpg 2x" width="120"/></a>
# <a href="/wiki/Kansas_City,_Missouri" title="Kansas City, Missouri">Kansas City, Missouri</a>
# <a href="/wiki/Cynodon_dactylon" title="Cynodon dactylon">Bermuda grass</a>
# <a href="/wiki/Kansas_City_Chiefs" title="Kansas City Chiefs">Kansas City Chiefs</a>
# <a href="#cite_note-4">[4]</a>
# ...

# %%
links = soup.findAll("img")

for i in links:
    h = i.get('src')
    print(h)
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Mercedes_Benz_Stadium_time_lapse_capture_2017-08-13.jpg/220px-Mercedes_Benz_Stadium_time_lapse_capture_2017-08-13.jpg
# //upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png
# //upload.wikimedia.org/wikipedia/commons/f/f9/Double-dagger-14-plain.png
# //upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Chiefsgame.jpg/120px-Chiefsgame.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Cowboys_Stadium_field.jpg/120px-Cowboys_Stadium_field.jpg
# //upload.wikimedia.org/wikipedia/commons/f/f9/Double-dagger-14-plain.png
# //upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Carolina_Panthers_24_Tampa_Bay_Bucanners_10.jpg/120px-Carolina_Panthers_24_Tampa_Bay_Bucanners_10.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Seahawksvcowboysatqwest.jpg/120px-Seahawksvcowboysatqwest.jpg
# ...

# %%
tables = pd.read_html(table_url)

# %%
len(tables)
# Out:
# 17

# %%
stadiums_df = tables[1]
stadiums_df.head()
# Out:
#    Image                        Name  Capacity                   Location  \
# 0    NaN           Arrowhead Stadium     76416      Kansas City, Missouri
# 1    NaN                AT&T Stadium     80000           Arlington, Texas
# 2    NaN     Bank of America Stadium     75523  Charlotte, North Carolina
# 3    NaN           CenturyLink Field     69000        Seattle, Washington
# 4    NaN  Dignity Health Sports Park     27000         Carson, California
#
#                        Surface    Roof type               Team(s) Opened  \
# 0                Bermuda grass         Open    Kansas City Chiefs   1972
# 1           Hellas Matrix Turf  Retractable        Dallas Cowboys   2009
# 2                Bermuda grass         Open     Carolina Panthers   1996
# 3  FieldTurf Revolution 360[8]         Open      Seattle Seahawks   2002
# 4                Bermuda grass         Open  Los Angeles Chargers   2003
#
#    Ref(s)
# 0     [4]
# 1  [5][6]
# 2     [7]
# 3     [9]
# 4    [10]

# %%
del stadiums_df['Image']
stadiums_df.head()
# Out:
#                          Name  Capacity                   Location  \
# 0           Arrowhead Stadium     76416      Kansas City, Missouri
# 1                AT&T Stadium     80000           Arlington, Texas
# 2     Bank of America Stadium     75523  Charlotte, North Carolina
# 3           CenturyLink Field     69000        Seattle, Washington
# 4  Dignity Health Sports Park     27000         Carson, California
#
#                        Surface    Roof type               Team(s) Opened  \
# 0                Bermuda grass         Open    Kansas City Chiefs   1972
# 1           Hellas Matrix Turf  Retractable        Dallas Cowboys   2009
# 2                Bermuda grass         Open     Carolina Panthers   1996
# 3  FieldTurf Revolution 360[8]         Open      Seattle Seahawks   2002
# 4                Bermuda grass         Open  Los Angeles Chargers   2003
#
#    Ref(s)
# 0     [4]
# 1  [5][6]
# 2     [7]
# 3     [9]
# 4    [10]

# %%
stadiums_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Capacity</th>\n      <th>Location</th>\n      <th>Surface</th>\n      <th>Roof type</th>\n      <th>Team(s)</th>\n      <th>Opened</th>\n      <th>Ref(s)</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Arrowhead Stadium</td>\n      <td>76416</td>\n      <td>Kansas City, Missouri</td>\n      <td>Bermuda grass</td>\n      <td>Open</td>\n      <td>Kansas City Chiefs</td>\n      <td>1972</td>\n      <td>[4]</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>AT&amp;T Stadium</td>\n      <td>80000</td>\n      <td>Arlington, Texas</td>\n      <td>Hellas Matrix Turf</td>\n      <td>Retractable</td>\n      <td>Dallas Cowboys</td>\n      <td>2009</td>\n      <td>[5][6]</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Bank of America Stadium</td>\n      <td>75523</td>\n      <td>Charlotte, North Carolina</td>\n      <td>Be
# ...

# %% [markdown]
# #  National Football League stadiums Img and info

# %%
table_url = "https://en.wikipedia.org/wiki/List_of_current_National_Football_League_stadiums"
browser.visit(table_url)
html = browser.html
soup = bs(html,"html.parser")

# %%
#print(soup.prettify())

# %%
stadiums_strings = stadiums_df['Name'].values.tolist()
stadiums_strings
# Out:
# ['Arrowhead Stadium',
#  'AT&T Stadium',
#  'Bank of America Stadium',
#  'CenturyLink Field',
#  'Dignity Health Sports Park',
#  'Empower Field at Mile High',
#  'FedExField',
#  'FirstEnergy Stadium',
#  'Ford Field',
#  'Gillette Stadium',
#  'Hard Rock Stadium',
#  'Heinz Field',
#  'Lambeau Field',
#  "Levi's Stadium",
#  'Lincoln Financial Field',
#  'Los Angeles Memorial Coliseum',
#  'Lucas Oil Stadium',
#  'M&T Bank Stadium',
#  'Mercedes-Benz Superdome',
#  'Mercedes-Benz Stadium',
#  'MetLife Stadium',
#  'New Era Field',
#  'Nissan Stadium',
#  'NRG Stadium',
#  'Paul Brown Stadium',
#  'Raymond James Stadium',
#  'RingCentral Coliseum',
#  'Soldier Field',
#  'State Farm Stadium',
#  'TIAA Bank Field',
#  'U.S. Bank Stadium']

# %%
stadiums_image_urls = []


for stadium in stadiums_strings:
    
    stadiums_dict = {}
    
    browser.click_link_by_partial_text(stadium)
    
    stadiums_dict["img_url: "] = browser.find_by_css('h1[class="site-headline"] img')
    
    stadiums_dict["title: "] = stadium
    
#    stadiums_dict["info: "] = ????
    
    stadiums_image_urls.append(stadiums_dict)
    
    #going back to the landing page
    browser.back()

# %%
stadiums_image_urls

for img in stadiums_image_urls
# Out:
# [{'img_url: ': <splinter.element_list.ElementList at 0x11a449198>,
#   'title: ': 'Arrowhead Stadium'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a18b0b8>,
#   'title: ': 'AT&T Stadium'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a4421d0>,
#   'title: ': 'Bank of America Stadium'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a197f98>,
#   'title: ': 'CenturyLink Field'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a7a7320>,
#   'title: ': 'Dignity Health Sports Park'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a7a74a8>,
#   'title: ': 'Empower Field at Mile High'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a79eb38>,
#   'title: ': 'FedExField'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a7a7278>,
#   'title: ': 'FirstEnergy Stadium'},
#  {'img_url: ': <splinter.element_list.ElementList at 0x11a7a74e0>,
#   'title: ': 'Ford Field'},
# ...

# %%
superbowl_url = "http://www.nfl.com/stats/categorystats?tabSeq=2&offensiveStatisticCategory=TEAM_PASSING&conference=ALL&role=TM&season=2018&seasonType=REG"
browser.visit(superbowl_url)
html = browser.html
soup = bs(html,"html.parser")

# %%
img = soup.find("yui_3_10_3_1_1574358207759_96")
# img_url = "https://www.jpl.nasa.gov" + img
print(img)
# Out:
# None

# %%
yui_3_10_3_1_1574358207759_96
